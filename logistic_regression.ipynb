# %% [markdown]
# <a href="https://colab.research.google.com/github/Gagan-2003/Intrusion-detection-using-machine-learning-algorithms/blob/main/logistic_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from google.colab import files


uploaded = files.upload()
# Out:
#      <input type="file" id="files-d9b18e81-79c4-421c-97d2-b9e156c018ad" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d9b18e81-79c4-421c-97d2-b9e156c018ad">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import io

df = pd.read_csv(io.BytesIO(uploaded['nsl-kdd.csv']))
print(df)
# Out:
#           id  duration protocol_type   service  flag  src_bytes  dst_bytes  \
# 0          1         0           tcp   private   REJ          0          0
# 1          2         0           tcp   private   REJ          0          0
# 2          3         2           tcp  ftp_data    SF      12983          0
# 3          4         0          icmp     eco_i    SF         20          0
# 4          5         1           tcp    telnet  RSTO          0         15
# ...      ...       ...           ...       ...   ...        ...        ...
# 22539  22540         0           tcp      smtp    SF        794        333
# 22540  22541         0           tcp      http    SF        317        938
# 22541  22542         0           tcp      http    SF      54540       8314
# 22542  22543         0           udp  domain_u    SF         42         42
# 22543  22544         0           tcp    sunrpc   REJ          0          0
#
#        land  wrong_fragment  urgent  ...  dst_host_srv_count  \
# ...

# %%
from sklearn import datasets
import numpy as nm
import matplotlib.pyplot as mtp
import pandas as pd

# %%
df['intrusion']=df['effect'].apply(lambda x: 1 if x=='anomaly' else 0)
df
# Out:
#           id  duration protocol_type   service  flag  src_bytes  dst_bytes  \
# 0          1         0           tcp   private   REJ          0          0
# 1          2         0           tcp   private   REJ          0          0
# 2          3         2           tcp  ftp_data    SF      12983          0
# 3          4         0          icmp     eco_i    SF         20          0
# 4          5         1           tcp    telnet  RSTO          0         15
# ...      ...       ...           ...       ...   ...        ...        ...
# 22539  22540         0           tcp      smtp    SF        794        333
# 22540  22541         0           tcp      http    SF        317        938
# 22541  22542         0           tcp      http    SF      54540       8314
# 22542  22543         0           udp  domain_u    SF         42         42
# 22543  22544         0           tcp    sunrpc   REJ          0          0
#
#        land  wrong_fragment  urgent  ...  dst_host_same_srv_rate  \
# ...

# %%
inputs = df.drop('intrusion',axis='columns')
target =df['intrusion']

# %%
from sklearn.preprocessing import LabelEncoder
le_protocol_type = LabelEncoder()
le_service = LabelEncoder()
le_flag = LabelEncoder()

# %%
inputs['protocol_type_n'] = le_protocol_type.fit_transform(inputs['protocol_type'])
inputs['service_n'] = le_protocol_type.fit_transform(inputs['service'])
inputs['flag_n'] = le_protocol_type.fit_transform(inputs['flag'])

# %%
inputs
# Out:
#           id  duration protocol_type   service  flag  src_bytes  dst_bytes  \
# 0          1         0           tcp   private   REJ          0          0
# 1          2         0           tcp   private   REJ          0          0
# 2          3         2           tcp  ftp_data    SF      12983          0
# 3          4         0          icmp     eco_i    SF         20          0
# 4          5         1           tcp    telnet  RSTO          0         15
# ...      ...       ...           ...       ...   ...        ...        ...
# 22539  22540         0           tcp      smtp    SF        794        333
# 22540  22541         0           tcp      http    SF        317        938
# 22541  22542         0           tcp      http    SF      54540       8314
# 22542  22543         0           udp  domain_u    SF         42         42
# 22543  22544         0           tcp    sunrpc   REJ          0          0
#
# ...

# %%
inputs_n = inputs.drop(['effect','protocol_type','service','flag','hot','num_failed_login','logged_in','land','wrong_fragment','num_compromised','root_shell','su_attempted','num_root','num_file_creations','num_shells','num_access_files','num_outbound_cmds','is_host_login','is_guest_login','srv_count','serror_rate','srv_serror_rate','rerror_rate','srv_rerror_rate','same_srv_rate','diff_srv_rate','srv_diff_host_rate','dst_host_count','dst_host_srv_count','dst_host_same_srv_rate','dst_host_diff_srv_rate','dst_host_same_src_port_rate','dst_host_srv_diff_host_rate','dst_host_serror_rate','dst_host_srv_serror_rate','dst_host_rerror_rate','dst_host_srv_rerror_rate'],axis='columns')

# %%
inputs_n
# Out:
#           id  duration  src_bytes  dst_bytes  urgent  count  protocol_type_n  \
# 0          1         0          0          0       0    229                1
# 1          2         0          0          0       0    136                1
# 2          3         2      12983          0       0      1                1
# 3          4         0         20          0       0      1                0
# 4          5         1          0         15       0      1                1
# ...      ...       ...        ...        ...     ...    ...              ...
# 22539  22540         0        794        333       0      1                1
# 22540  22541         0        317        938       0      2                1
# 22541  22542         0      54540       8314       0      5                1
# 22542  22543         0         42         42       0      4                2
# 22543  22544         0          0          0       0      4                1
#
#        service_n  flag_n
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(inputs,target,test_size=0.2)

# %%
target
# Out:
# 0        1
# 1        1
# 2        0
# 3        1
# 4        1
#         ..
# 22539    0
# 22540    0
# 22541    1
# 22542    0
# 22543    1
# Name: intrusion, Length: 22544, dtype: int64

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(inputs_n,target)
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
model.predict([[1,0,0,0,0,229,1,45,1]])
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([1])

# %%
model.score(inputs_n,target)
# Out:
# 0.8246983676366217

# %%
from sklearn.metrics import confusion_matrix
y_pred = model.predict(inputs_n)
cm = confusion_matrix(target, y_pred)
cm
# Out:
# array([[ 8062,  1649],
#        [ 2303, 10530]])

# %%
from sklearn.metrics import classification_report
print(classification_report(target, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.83      0.80      9711
#            1       0.86      0.82      0.84     12833
#
#     accuracy                           0.82     22544
#    macro avg       0.82      0.83      0.82     22544
# weighted avg       0.83      0.82      0.83     22544
